# %% [markdown]
# #**Omer Imran**
# ##Master's of Information candidate in Human-Centered Data Science

# %% [markdown]
# #Data Cleanig

# %% [markdown]
# This is my mid-term submission for INF1340. My name is Omer Imran and I'll be taking you through my code.
#
# Here's how the code is distributed
# 1. Imports
# 2. Functions
# 3. Tidying the Data
#
# I would recommend keeping the write up open with at all times to further streamline your grading experience. I will be commenting as much as possible to keep the code as human-centered as possible ;)

# %% [markdown]
# ### Important Note!

# %% [markdown]
# Some of this code may seem familiar. And it is! I took inspiration from Shion's code from in-class. If I use code from some online resource. You'll see a citation in this section.

# %% [markdown]
# Format Text In Jupyter Notebook With Markdown: https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-text-files/format-text-with-markdown-jupyter-notebook/

# %% [markdown]
# Additionally, I used code from our class as well from Pandas documentation.

# %% [markdown]
# ## 1. Imports

# %% [markdown]
# In this section, there is just one cell that defines what sort of libraries I am importing.

# %%
import pandas as pd

# %% [markdown]
# ## 2. Functions

# %% [markdown]
# Here I write code for any functions that I will be utilizing in later sections of the notebook. Feel free to jump back here to understand how I'm using functions that I create.

# %%
#The add_Major_region functions below are used to add Major region into a separate column.

def add_Major_region (df):
    cells = range(8,70)
    for i in cells:
        df.iloc[i, 2] = "Africa"
    cells = range(71,126)
    for i in cells:
        df.iloc[i, 2] = "Asia"
    cells = range(127,179)
    for i in cells:
        df.iloc[i, 2] = "Europe"
    cells = range(180,231)
    for i in cells:
        df.iloc[i, 2] = "Latin America and the Caribbean"
    cells = range(232,237)
    for i in cells:
        df.iloc[i, 2] = "Northern America"
    cells = range(238,265)
    for i in cells:
        df.iloc[i, 2] = "Oceania"

#The add_Region functions below are used to add region into a separate column.
def add_Region (df):
    cells = range(8,28)
    for i in cells:
        df.iloc[i, 3] = "Eastern Africa"
    cells = range(29,38)
    for i in cells:
        df.iloc[i, 3] = "Middle Africa"
    cells = range(39,46)
    for i in cells:
        df.iloc[i, 3] = "Northern Africa"
    cells = range(47,52)
    for i in cells:
        df.iloc[i, 3] = "Southern Africa"
    cells = range(53,70)
    for i in cells:
        df.iloc[i, 3] = "Western Africa"
    cells = range(72,77)
    for i in cells:
        df.iloc[i, 3] = "Central Asia"
    cells = range(78,85)
    for i in cells:
        df.iloc[i, 3] = "Eastern Asia"
    cells = range(86,97)
    for i in cells:
        df.iloc[i, 3] = "South-Eastern Asia"
    cells = range(98,107)
    for i in cells:
        df.iloc[i, 3] = "Southern Asia"
    cells = range(108,126)
    for i in cells:
        df.iloc[i, 3] = "Western Asia"
    cells = range(128,138)
    for i in cells:
        df.iloc[i, 3] = "Eastern Europe"
    cells = range(139,152)
    for i in cells:
        df.iloc[i, 3] = "Northern Europe"
    cells = range(153,169)
    for i in cells:
        df.iloc[i, 3] = "Southern Europe"
    cells = range(170,179)
    for i in cells:
        df.iloc[i, 3] = "Western Europe"
    cells = range(181,207)
    for i in cells:
        df.iloc[i, 3] = "Caribbean"
    cells = range(208,216)
    for i in cells:
        df.iloc[i, 3] = "Central America"
    cells = range(217,231)
    for i in cells:
        df.iloc[i, 3] = "South America"
    cells = range(232,237)
    for i in cells:
        df.iloc[i, 3] = "Northern America"
    cells = range(239,241)
    for i in cells:
        df.iloc[i, 3] = "Australia and New Zealand"
    cells = range(242,247)
    for i in cells:
        df.iloc[i, 3] = "Melanesia"
    cells = range(248,255)
    for i in cells:
        df.iloc[i, 3] = "Micronesia"
    cells = range(256,265)
    for i in cells:
        df.iloc[i, 3] = "Polynesia"
        
#This function adds into the column of "Developed/Developing" whether a country is developing or not.
#Criteria is chosen NOTES table in excel file. 

def developing (df):
    cells = range(0,265)
    for i in cells:
        if df.iloc[i, 1] == 'Australia' or df.iloc[i, 1] == 'New Zealand' or df.iloc[i, 1] == 'Japan':
            df.iloc[i, 4] = 'Developed'
        elif df.iloc[i, 2] == 'Europe' or df.iloc[i, 2] == 'Northern America':
            df.iloc[i, 4] = 'Developed'
        else:
            df.iloc[i, 4] = 'Developing'
            
#This function checks the values in "Type of data(a)" column and accordingly sets values to true or false in their
#respective columns. 

def type_of_data (df):
    cells = range(0, 265)
    
    for i in cells:
        if isinstance(df.iloc[i, 7], str):
            if "B" in df.iloc[i, 7]:
                df.iloc[i, 8] = 1
            if "C" in df.iloc[i, 7]:
                df.iloc[i, 9] = 1
            if "R" in df.iloc[i, 7]:
                df.iloc[i, 10] = 1
            if "I" in df.iloc[i, 7]:
                df.iloc[i, 11] = 1

# %% [markdown]
# ## 3. Tidying the Data

# %% [markdown]
# This is where the real fun begins. In this section, we'll be properly loading, cleaning, and then saving the final data set from the UN dataset. Good luck!

# %% [markdown]
# ## 3.1 Loading the Dataset

# %%
#Loading all the datasets into dataframes. 

#You will need to change this according to your directory
#filename = "/Users/omerimran/Downloads/UN_MigrantStockTotal_2015.xlsx"

#And this is the format for the colab notebook
filename = "UN_MigrantStockTotal_2015.xlsx"

#The number in-front of df indicates which table it imported. For example df_1 is the dataframe created from table 1 of the dataset.
df_1 = pd.read_excel(filename, "Table 1")
df_2 = pd.read_excel(filename, "Table 2")
df_3 = pd.read_excel(filename, "Table 3")
df_4 = pd.read_excel(filename, "Table 4")
df_5 = pd.read_excel(filename, "Table 5")
df_6 = pd.read_excel(filename, "Table 6")

# %% [markdown]
# ## 3.2 Cleaning

# %% [markdown]
# ### 3.2.1 Table 1

# %%
#We'll start with table 1 of course. Most of what we do here will be repeatable in other tables.

df_1.head(25)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. We'll rename the columns using a fucntion. 

df_1 = df_1.drop(df_1.index[0:15], axis = 0)
df_1.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
#We will now fix the columns. We need to rename them.

df_1 = df_1.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "Type of data (a)",
                  "Unnamed: 5": "1990Both",
                  "Unnamed: 6": "1995Both",
                  "Unnamed: 7": "2000Both",
                  "Unnamed: 8": "2005Both",
                  "Unnamed: 9": "2010Both",
                  "Unnamed: 10": "2015Both",
                  "Unnamed: 11": "1990Male",
                  "Unnamed: 12": "1995Male",
                  "Unnamed: 13": "2000Male",
                  "Unnamed: 14": "2005Male",
                  "Unnamed: 15": "2010Male",
                  "Unnamed: 16": "2015Male",
                  "Unnamed: 17": "1990Female",
                  "Unnamed: 18": "1995Female",
                  "Unnamed: 19": "2000Female",
                  "Unnamed: 20": "2005Female",
                  "Unnamed: 21": "2010Female",
                  "Unnamed: 22": "2015Female",
                 }, axis=1)

df_1.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_1.insert(2,'Major region', None )
df_1.insert(3,'Region', None )
df_1.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a)   1990Both   1995Both  \
# 15   None   NaN          900              NaN  152563212  160801752
# 16   None   (b)          901              NaN   82378628   92306854
# 17   None   (c)          902              NaN   70184584   68494898
# 18   None   (d)          941              NaN   11075966   11711703
# 19   None   NaN          934              NaN   59105261   56778501
#
#      2000Both  ...  2000Male  2005Male     2010Male     2015Male 1990Female  \
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_1)
add_Region(df_1)

df_1.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a)   1990Both  \
# 15          None       None   NaN          900              NaN  152563212
# ...

# %%
#We are creating a new column "developed/developing" 
df_1.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_1)
df_1.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_1.insert(8,'I', 0 )
df_1.insert(8,'R', 0 )
df_1.insert(8,'C', 0 )
df_1.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_1)

df_1.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Removing reduntant rows of regions and major regions
df_1 = df_1.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_1 = df_1.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_1 = df_1.reset_index() #Do we need brackets here
df_1 = df_1.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_1 = df_1.drop("Notes", axis = 1)
df_1 = df_1.drop("Type of data (a)", axis = 1)

df_1.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and migrant stock columns

df_1 = df_1.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="migrant stock")
df_1.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 4126                                             Belize
# 4127                                         Costa Rica
# 4128                                        El Salvador
# 4129                                          Guatemala
# 4130                                           Honduras
# 4131                                             Mexico
# 4132                                          Nicaragua
# 4133                                             Panama
# 4134                                          Argentina
# 4135                   Bolivia (Plurinational State of)
# 4136                                             Brazil
# 4137                                              Chile
# 4138                                           Colombia
# 4139                                            Ecuador
# 4140                        Falkland Islands (Malvinas)
# 4141                                      French Guiana
# ...

# %%
#Took this code from Shion's Class
#We are separating year and gender from the time column created during melting
df_1=(df_1.assign(gender = lambda x: x.time.str[4:].astype(str), year = lambda x: x.time.str[0:4].astype(str)).drop("time",axis=1))
df_1.head(5)
# Out:
#   Major area, region, country or area of destination Major region  \
# 0                                            Burundi       Africa
# 1                                            Comoros       Africa
# 2                                           Djibouti       Africa
# 3                                            Eritrea       Africa
# 4                                           Ethiopia       Africa
#
#            Region developed/developing Country code  B  C  R  I migrant stock  \
# 0  Eastern Africa           Developing          108  1  0  1  0        333110
# 1  Eastern Africa           Developing          174  1  0  0  0         14079
# 2  Eastern Africa           Developing          262  1  0  1  0        122221
# 3  Eastern Africa           Developing          232  0  0  0  1         11848
# 4  Eastern Africa           Developing          231  1  0  1  0       1155390
#
#   gender  year
# 0   Both  1990
# 1   Both  1990
# 2   Both  1990
# 3   Both  1990
# 4   Both  1990

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_1 = df_1.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i"})
df_1 = df_1[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "migrant stock","year", "gender"]]

# %%
df_1.shape
# Out:
# (4176, 12)

# %%
df_1.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   migrant stock  year gender
# 0        333110  1990   Both
# 1         14079  1990   Both
# 2        122221  1990   Both
# 3         11848  1990   Both
# 4       1155390  1990   Both

# %% [markdown]
# We are done with Table 1! Yay! The process is almost identical for the rest of the tables. Before we move onto the next table I would like to describe the final nature of table 1. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - migrant stock: international migrant stock at mid-year
# - year: the year of the stock
# - gender: whether stock is of male, female, or both

# %% [markdown]
# ### 3.2.2 Table 2

# %%
df_2.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. 

df_2 = df_2.drop(df_2.index[0:15], axis = 0)
df_2.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
df_2 = df_2.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "1990Both",
                  "Unnamed: 5": "1995Both",
                  "Unnamed: 6": "2000Both",
                  "Unnamed: 7": "2005Both",
                  "Unnamed: 8": "2010Both",
                  "Unnamed: 9": "2015Both",
                  "Unnamed: 10": "1990Male",
                  "Unnamed: 11": "1995Male",
                  "Unnamed: 12": "2000Male",
                  "Unnamed: 13": "2005Male",
                  "Unnamed: 14": "2010Male",
                  "Unnamed: 15": "2015Male",
                  "Unnamed: 16": "1990Female",
                  "Unnamed: 17": "1995Female",
                  "Unnamed: 18": "2000Female",
                  "Unnamed: 19": "2005Female",
                  "Unnamed: 20": "2010Female",
                  "Unnamed: 21": "2015Female",
                 }, axis=1)

df_2.head()
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
#
#    Country code     1990Both     1995Both     2000Both     2005Both  \
# 15          900  5309667.699  5735123.084  6126622.121  6519635.850
# 16          901  1144463.062  1169761.211  1188811.731  1208919.509
# 17          902  4165204.637  4565361.873  4937810.390  5310716.341
# 18          941   510057.629   585189.354   664386.087   752804.951
# 19          934  3655147.008  3980172.519  4273424.303  4557911.390
#
#        2010Both     2015Both  ...     2000Male     2005Male     2010Male  \
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_2.insert(2,'Major region', None )
df_2.insert(3,'Region', None )
df_2.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code     1990Both     1995Both     2000Both  \
# 15   None   NaN          900  5309667.699  5735123.084  6126622.121
# 16   None   (b)          901  1144463.062  1169761.211  1188811.731
# 17   None   (c)          902  4165204.637  4565361.873  4937810.390
# 18   None   (d)          941   510057.629   585189.354   664386.087
# 19   None   NaN          934  3655147.008  3980172.519  4273424.303
#
#        2005Both  ...     2000Male     2005Male     2010Male     2015Male  \
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_2)
add_Region(df_2)

df_2.head(50)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#We are creating a new column "developed/developing" 
df_2.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_2)
df_2.head(30)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Removing reduntant rows of regions and major regions
df_2 = df_2.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_2 = df_2.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_2 = df_2.reset_index() #Do we need brackets here
df_2 = df_2.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_2 = df_2.drop("Notes", axis = 1)

df_2.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and population columns

df_2 = df_2.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code"], var_name = "time", value_name="total population")
df_2.head(50)
# Out:
#    Major area, region, country or area of destination Major region  \
# 0                                             Burundi       Africa
# 1                                             Comoros       Africa
# 2                                            Djibouti       Africa
# 3                                             Eritrea       Africa
# 4                                            Ethiopia       Africa
# 5                                               Kenya       Africa
# 6                                          Madagascar       Africa
# 7                                              Malawi       Africa
# 8                                           Mauritius       Africa
# 9                                             Mayotte       Africa
# 10                                         Mozambique       Africa
# 11                                            Réunion       Africa
# 12                                             Rwanda       Africa
# ...

# %%
#Took this code from Shion's Class
#We are separating year and gender from the time column created during melting
df_2=(df_2.assign(gender = lambda x: x.time.str[4:].astype(str), year = lambda x: x.time.str[0:4].astype(str)).drop("time",axis=1))
df_2.head(5)
# Out:
#   Major area, region, country or area of destination Major region  \
# 0                                            Burundi       Africa
# 1                                            Comoros       Africa
# 2                                           Djibouti       Africa
# 3                                            Eritrea       Africa
# 4                                           Ethiopia       Africa
#
#            Region developed/developing Country code total population gender  \
# 0  Eastern Africa           Developing          108         5613.141   Both
# 1  Eastern Africa           Developing          174          415.144   Both
# 2  Eastern Africa           Developing          262          588.356   Both
# 3  Eastern Africa           Developing          232         3139.083   Both
# 4  Eastern Africa           Developing          231        48057.094   Both
#
#    year
# 0  1990
# 1  1990
# 2  1990
# 3  1990
# 4  1990

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_2 = df_2.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development"})
df_2 = df_2[["country", "country code", "continent", "region", "development", "total population","year", "gender"]]

# %%
df_2.shape
# Out:
# (4176, 8)

# %%
df_2.head(10)
# Out:
#       country country code continent          region development  \
# 0     Burundi          108    Africa  Eastern Africa  Developing
# 1     Comoros          174    Africa  Eastern Africa  Developing
# 2    Djibouti          262    Africa  Eastern Africa  Developing
# 3     Eritrea          232    Africa  Eastern Africa  Developing
# 4    Ethiopia          231    Africa  Eastern Africa  Developing
# 5       Kenya          404    Africa  Eastern Africa  Developing
# 6  Madagascar          450    Africa  Eastern Africa  Developing
# 7      Malawi          454    Africa  Eastern Africa  Developing
# 8   Mauritius          480    Africa  Eastern Africa  Developing
# 9     Mayotte          175    Africa  Eastern Africa  Developing
#
#   total population  year gender
# 0         5613.141  1990   Both
# 1          415.144  1990   Both
# 2          588.356  1990   Both
# 3         3139.083  1990   Both
# 4        48057.094  1990   Both
# 5        23446.229  1990   Both
# ...

# %% [markdown]
# We are done with Table 2 as well! Now we just rinse and repeat. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - total population: total population at mid-year in thousands
# - year: the year of the stock
# - gender: whether stock is of male, female, or both

# %% [markdown]
# ### 3.2.3 Table 3

# %%
df_3.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 1        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 2        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 3        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 4        NaN        NaN        NaN         NaN  ...          NaN         NaN
#
# ...

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. 

df_3 = df_3.drop(df_3.index[0:15], axis = 0)
df_3.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
#We will now fix the columns. We need to rename them.

df_3 = df_3.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "Type of data (a)",
                  "Unnamed: 5": "1990Both",
                  "Unnamed: 6": "1995Both",
                  "Unnamed: 7": "2000Both",
                  "Unnamed: 8": "2005Both",
                  "Unnamed: 9": "2010Both",
                  "Unnamed: 10": "2015Both",
                  "Unnamed: 11": "1990Male",
                  "Unnamed: 12": "1995Male",
                  "Unnamed: 13": "2000Male",
                  "Unnamed: 14": "2005Male",
                  "Unnamed: 15": "2010Male",
                  "Unnamed: 16": "2015Male",
                  "Unnamed: 17": "1990Female",
                  "Unnamed: 18": "1995Female",
                  "Unnamed: 19": "2000Female",
                  "Unnamed: 20": "2005Female",
                  "Unnamed: 21": "2010Female",
                  "Unnamed: 22": "2015Female",
                 }, axis=1)

df_3.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_3.insert(2,'Major region', None )
df_3.insert(3,'Region', None )
df_3.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a)  1990Both  1995Both  2000Both  \
# 15   None   NaN          900              NaN   2.87331  2.803806  2.818899
# 16   None   (b)          901              NaN  7.198015  7.891085  8.695688
# 17   None   (c)          902              NaN  1.685021  1.500317  1.404022
# 18   None   (d)          941              NaN  2.171513  2.001353  1.516863
# 19   None   NaN          934              NaN  1.617042  1.426534  1.386338
#
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_3)
add_Region(df_3)

df_3.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a)   1990Both  \
# 15          None       None   NaN          900              NaN    2.87331
# ...

# %%
#We are creating a new column "developed/developing" 
df_3.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_3)
df_3.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_3.insert(8,'I', 0 )
df_3.insert(8,'R', 0 )
df_3.insert(8,'C', 0 )
df_3.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_3)

df_3.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Removing reduntant rows of regions and major regions
df_3 = df_3.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_3 = df_3.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_3 = df_3.reset_index() #Do we need brackets here
df_3 = df_3.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_3 = df_3.drop("Notes", axis = 1)
df_3 = df_3.drop("Type of data (a)", axis = 1)

df_3.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and migrant stock columns

df_3 = df_3.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="migrant stock in %")
df_3.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 4126                                             Belize
# 4127                                         Costa Rica
# 4128                                        El Salvador
# 4129                                          Guatemala
# 4130                                           Honduras
# 4131                                             Mexico
# 4132                                          Nicaragua
# 4133                                             Panama
# 4134                                          Argentina
# 4135                   Bolivia (Plurinational State of)
# 4136                                             Brazil
# 4137                                              Chile
# 4138                                           Colombia
# 4139                                            Ecuador
# 4140                        Falkland Islands (Malvinas)
# 4141                                      French Guiana
# ...

# %%
#Took this code from Shion's Class
#We are separating year and gender from the time column created during melting
df_3=(df_3.assign(gender = lambda x: x.time.str[4:].astype(str), year = lambda x: x.time.str[0:4].astype(str)).drop("time",axis=1))
df_3.head(5)
# Out:
#   Major area, region, country or area of destination Major region  \
# 0                                            Burundi       Africa
# 1                                            Comoros       Africa
# 2                                           Djibouti       Africa
# 3                                            Eritrea       Africa
# 4                                           Ethiopia       Africa
#
#            Region developed/developing Country code  B  C  R  I  \
# 0  Eastern Africa           Developing          108  1  0  1  0
# 1  Eastern Africa           Developing          174  1  0  0  0
# 2  Eastern Africa           Developing          262  1  0  1  0
# 3  Eastern Africa           Developing          232  0  0  0  1
# 4  Eastern Africa           Developing          231  1  0  1  0
#
#   migrant stock in % gender  year
# 0           5.934467   Both  1990
# 1           3.391353   Both  1990
# 2          20.773307   Both  1990
# 3           0.377435   Both  1990
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_3 = df_3.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i"})
df_3 = df_3[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "migrant stock in %","year", "gender"]]

df_3.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   migrant stock in %  year gender
# 0           5.934467  1990   Both
# 1           3.391353  1990   Both
# 2          20.773307  1990   Both
# 3           0.377435  1990   Both
# 4           2.404203  1990   Both

# %%
df_3.shape
# Out:
# (4176, 12)

# %% [markdown]
# We are done with Table 3. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - migrant stock in %: international migrant stock at mid-year as a % of total population
# - year: the year of the stock
# - gender: whether stock is of male, female, or both

# %% [markdown]
# ### 3.2.4 Table 4

# %%
df_4.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. 

df_4 = df_4.drop(df_4.index[0:15], axis = 0)
df_4.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
#We will now fix the columns. We need to rename them.

df_4 = df_4.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "Type of data (a)",
                  "Unnamed: 5": "1990",
                  "Unnamed: 6": "1995",
                  "Unnamed: 7": "2000",
                  "Unnamed: 8": "2005",
                  "Unnamed: 9": "2010",
                  "Unnamed: 10": "2015",
                 }, axis=1)

df_4.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_4.insert(2,'Major region', None )
df_4.insert(3,'Region', None )
df_4.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a)       1990       1995  \
# 15   None   NaN          900              NaN   49.03915   49.16879
# 16   None   (b)          901              NaN  51.123977  51.149024
# 17   None   (c)          902              NaN  46.592099  46.500135
# 18   None   (d)          941              NaN  47.261155  47.571664
# 19   None   NaN          934              NaN  46.466684  46.279022
#
#          2000       2005       2010       2015
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_4)
add_Region(df_4)

df_4.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a)       1990  \
# 15          None       None   NaN          900              NaN   49.03915
# ...

# %%
#We are creating a new column "developed/developing" 
df_4.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_4)
df_4.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_4.insert(8,'I', 0 )
df_4.insert(8,'R', 0 )
df_4.insert(8,'C', 0 )
df_4.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_4)

df_4.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#### Removing reduntant rows of regions and major regions
df_4 = df_4.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_4 = df_4.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_4 = df_4.reset_index() #Do we need brackets here
df_4 = df_4.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_4 = df_4.drop("Notes", axis = 1)
df_4 = df_4.drop("Type of data (a)", axis = 1)

df_4.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and migrant stock columns

df_4 = df_4.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="female migrants as %")
df_4.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 1342                                             Belize
# 1343                                         Costa Rica
# 1344                                        El Salvador
# 1345                                          Guatemala
# 1346                                           Honduras
# 1347                                             Mexico
# 1348                                          Nicaragua
# 1349                                             Panama
# 1350                                          Argentina
# 1351                   Bolivia (Plurinational State of)
# 1352                                             Brazil
# 1353                                              Chile
# 1354                                           Colombia
# 1355                                            Ecuador
# 1356                        Falkland Islands (Malvinas)
# 1357                                      French Guiana
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_4 = df_4.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i", "time":"year"})
df_4 = df_4[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "female migrants as %","year"]]

df_4.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   female migrants as %  year
# 0            50.987061  1990
# 1            52.290646  1990
# 2            47.437838  1990
# 3            47.434166  1990
# 4            47.439047  1990

# %%
df_4.shape
# Out:
# (1392, 11)

# %% [markdown]
# We are done with Table 4. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - female migrants as %: female migrants as % of international migrant stock at mid-year
# - year: the year of the stock

# %% [markdown]
# ### 3.2.5 Table 5

# %%
df_5.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
# ...

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. 

df_5 = df_5.drop(df_5.index[0:15], axis = 0)
df_5.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
df_5.shape
# Out:
# (265, 20)

# %%
#We will now fix the columns. We need to rename them.

df_5 = df_5.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "Type of data (a)",
                  "Unnamed: 5": "1990-1995Both",
                  "Unnamed: 6": "1995-2000Both",
                  "Unnamed: 7": "2000-2005Both",
                  "Unnamed: 8": "2005-2010Both",
                  "Unnamed: 9": "2010-2015Both",
                  "Unnamed: 10": "1990-1995Male",
                  "Unnamed: 11": "1995-2000Male",
                  "Unnamed: 12": "2000-2005Male",
                  "Unnamed: 13": "2005-2010Male",
                  "Unnamed: 14": "2010-2015Male",
                  "Unnamed: 15": "1990-1995Female",
                  "Unnamed: 16": "1995-2000Female",
                  "Unnamed: 17": "2000-2005Female",
                  "Unnamed: 18": "2005-2010Female",
                  "Unnamed: 19": "2010-2015Female"
                 }, axis=1)

df_5.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_5.insert(2,'Major region', None )
df_5.insert(3,'Region', None )
df_5.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a) 1990-1995Both 1995-2000Both  \
# 15   None   NaN          900              NaN      1.051865      1.428058
# 16   None   (b)          901              NaN      2.275847      2.264965
# 17   None   (c)          902              NaN     -0.487389      0.241777
# 18   None   (d)          941              NaN      1.118175     -3.001139
# 19   None   NaN          934              NaN     -0.803244      0.850177
#
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_5)
add_Region(df_5)

df_5.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a) 1990-1995Both  \
# 15          None       None   NaN          900              NaN      1.051865
# ...

# %%
#We are creating a new column "developed/developing" 
df_5.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_5)
df_5.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_5.insert(8,'I', 0 )
df_5.insert(8,'R', 0 )
df_5.insert(8,'C', 0 )
df_5.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_5)

df_5.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#### Removing reduntant rows of regions and major regions
df_5 = df_5.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_5 = df_5.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_5 = df_5.reset_index() #Do we need brackets here
df_5 = df_5.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_5 = df_5.drop("Notes", axis = 1)
df_5 = df_5.drop("Type of data (a)", axis = 1)

df_5.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and migrant stock columns

df_5 = df_5.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="rate of change in migrant stock")
df_5.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 3430                                             Belize
# 3431                                         Costa Rica
# 3432                                        El Salvador
# 3433                                          Guatemala
# 3434                                           Honduras
# 3435                                             Mexico
# 3436                                          Nicaragua
# 3437                                             Panama
# 3438                                          Argentina
# 3439                   Bolivia (Plurinational State of)
# 3440                                             Brazil
# 3441                                              Chile
# 3442                                           Colombia
# 3443                                            Ecuador
# 3444                        Falkland Islands (Malvinas)
# 3445                                      French Guiana
# ...

# %%
#Took this code from Shion's Class
#We are separating year and gender from the time column created during melting
df_5=(df_5.assign(gender = lambda x: x.time.str[9:].astype(str), year = lambda x: x.time.str[0:9].astype(str)).drop("time",axis=1))
df_5.head(5)
# Out:
#   Major area, region, country or area of destination Major region  \
# 0                                            Burundi       Africa
# 1                                            Comoros       Africa
# 2                                           Djibouti       Africa
# 3                                            Eritrea       Africa
# 4                                           Ethiopia       Africa
#
#            Region developed/developing Country code  B  C  R  I  \
# 0  Eastern Africa           Developing          108  1  0  1  0
# 1  Eastern Africa           Developing          174  1  0  0  0
# 2  Eastern Africa           Developing          262  1  0  1  0
# 3  Eastern Africa           Developing          232  0  0  0  1
# 4  Eastern Africa           Developing          231  1  0  1  0
#
#   rate of change in migrant stock gender       year
# 0                       -5.355717   Both  1990-1995
# 1                       -0.199873   Both  1990-1995
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_5 = df_5.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i", "year":"period"})
df_5 = df_5[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "rate of change in migrant stock","period"]]

df_5.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   rate of change in migrant stock     period
# 0                       -5.355717  1990-1995
# 1                       -0.199873  1990-1995
# 2                       -4.058465  1990-1995
# 3                        0.910748  1990-1995
# 4                       -7.179771  1990-1995

# %%
df_5.shape
# Out:
# (3480, 11)

# %% [markdown]
# We are done with Table 5. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - rate of change in migrant stock: annual rate of change of migrant stock in percentage
# - period: the years of the change value

# %% [markdown]
# ### 3.2.6 Table 6

# %% [markdown]
# Here the process changes slightly. In the columns of this table we see two different methods of recording the time i.e. yearly and in time-periods (a measurement every 5 years). Additionally, there are three units of measurement. As a result we will split the dataset into three more tables giving us a total of 8 tables.

# %% [markdown]
# We'll break it down like this:
# - df_6: Refugee Stock at mid-year (both sexes)
# - df_7: Refugees as percentage of international migrant stock
# - df_8: Annual rate of change of the refugee stock

# %%
#Let's drop the first 15 rows. We've got a lot of cluter there. 

df_6 = df_6.drop(df_5.index[0:15], axis = 0)
df_6.head(20)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
# 20          6                                 Sub-Saharan Africa        (e)
# 21          7                                             Africa        NaN
# 22          8                                     Eastern Africa        NaN
# 23          9                                            Burundi        NaN
# 24         10                                            Comoros        NaN
# 25         11                                           Djibouti        NaN
# ...

# %%
#We will now fix the columns. We need to rename them.

df_6 = df_6.rename({"Unnamed: 0": "Sort order",
                  "Unnamed: 1": "Major area, region, country or area of destination",
                  "Unnamed: 2": "Notes",
                  "Unnamed: 3": "Country code",
                  "Unnamed: 4": "Type of data (a)",
                  "Unnamed: 5": "1990 Refugee",
                  "Unnamed: 6": "1995 Refugee",
                  "Unnamed: 7": "2000 Refugee",
                  "Unnamed: 8": "2005 Refugee",
                  "Unnamed: 9": "2010 Refugee",
                  "Unnamed: 10": "2015 Refugee",
                  "Unnamed: 11": "1990 %",
                  "Unnamed: 12": "1995 %",
                  "Unnamed: 13": "2000 %",
                  "Unnamed: 14": "2005 %",
                  "Unnamed: 15": "2010 %",
                  "Unnamed: 16": "2015 %",
                  "Unnamed: 17": "1990-1995",
                  "Unnamed: 18": "1995-2000",
                  "Unnamed: 19": "2000-2005",
                  "Unnamed: 20": "2005-2010",
                  "Unnamed: 21": "2010-2015"
                 }, axis=1)
                    

df_6.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#Creating duplicates of Table 6
df_7 = df_6[["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990 %", "1995 %", "2000 %", "2005 %", "2010 %", "2015 %"]]
df_8 = df_6[["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990-1995", "1995-2000", "2000-2005", "2005-2010", "2010-2015"]]

# %%
#We will now work on df_6 first. We will keep only the estimated refugee stock columns
df_6 = df_6[["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990 Refugee", "1995 Refugee", "2000 Refugee", "2005 Refugee", "2010 Refugee", "2015 Refugee"]]

# %%
df_6.head(20)
# Out:
#    Sort order Major area, region, country or area of destination Notes  \
# 15          1                                              WORLD   NaN
# 16          2                                  Developed regions   (b)
# 17          3                                 Developing regions   (c)
# 18          4                          Least developed countries   (d)
# 19          5  Less developed regions excluding least develop...   NaN
# 20          6                                 Sub-Saharan Africa   (e)
# 21          7                                             Africa   NaN
# 22          8                                     Eastern Africa   NaN
# 23          9                                            Burundi   NaN
# 24         10                                            Comoros   NaN
# 25         11                                           Djibouti   NaN
# 26         12                                            Eritrea   NaN
# ...

# %%
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_6.insert(2,'Major region', None )
df_6.insert(3,'Region', None )
df_6.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a) 1990 Refugee 1995 Refugee  \
# 15   None   NaN          900              NaN     18836571     17853840
# 16   None   (b)          901              NaN      2014564      3609670
# 17   None   (c)          902              NaN     16822007     14244170
# 18   None   (d)          941              NaN      5048391      5160131
# 19   None   NaN          934              NaN     11773616      9084039
#
#    2000 Refugee 2005 Refugee  2010 Refugee  2015 Refugee
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_6)
add_Region(df_6)

df_6.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a) 1990 Refugee  \
# 15          None       None   NaN          900              NaN     18836571
# ...

# %%
#We are creating a new column "developed/developing" 
df_6.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_6)
df_6.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_6.insert(8,'I', 0 )
df_6.insert(8,'R', 0 )
df_6.insert(8,'C', 0 )
df_6.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_6)

df_6.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#### Removing reduntant rows of regions and major regions
df_6 = df_6.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_6 = df_6.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_6 = df_6.reset_index() #Do we need brackets here
df_6 = df_6.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_6 = df_6.drop("Notes", axis = 1)
df_6 = df_6.drop("Type of data (a)", axis = 1)

df_6.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Before melting, I am going to change the names of the columns. 

df_6 = df_6.rename({"1990 Refugee": "1990",
             "1995 Refugee": "1995",
             "2000 Refugee": "2000",
             "2005 Refugee": "2005",
             "2010 Refugee": "2010",
             "2015 Refugee": "2015"
            }, axis = 1)

# %%
df_6.head(5)
# Out:
#   Major area, region, country or area of destination Major region  \
# 0                                            Burundi       Africa
# 1                                            Comoros       Africa
# 2                                           Djibouti       Africa
# 3                                            Eritrea       Africa
# 4                                           Ethiopia       Africa
#
#            Region developed/developing Country code  B  C  R  I    1990  \
# 0  Eastern Africa           Developing          108  1  0  1  0  267929
# 1  Eastern Africa           Developing          174  1  0  0  0       0
# 2  Eastern Africa           Developing          262  1  0  1  0   54508
# 3  Eastern Africa           Developing          232  0  0  0  1       0
# 4  Eastern Africa           Developing          231  1  0  1  0  741965
#
#      1995    2000    2005      2010      2015
# 0  173017   27136   20681   29365.0   47805.0
# ...

# %%
#Here we melt all the year and migrant stock columns

df_6 = df_6.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="refugee stock")
df_6.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 1342                                             Belize
# 1343                                         Costa Rica
# 1344                                        El Salvador
# 1345                                          Guatemala
# 1346                                           Honduras
# 1347                                             Mexico
# 1348                                          Nicaragua
# 1349                                             Panama
# 1350                                          Argentina
# 1351                   Bolivia (Plurinational State of)
# 1352                                             Brazil
# 1353                                              Chile
# 1354                                           Colombia
# 1355                                            Ecuador
# 1356                        Falkland Islands (Malvinas)
# 1357                                      French Guiana
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_6 = df_6.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i", "time":"year"})
df_6 = df_6[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "refugee stock","year"]]

df_6.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   refugee stock  year
# 0        267929  1990
# 1             0  1990
# 2         54508  1990
# 3             0  1990
# 4        741965  1990

# %%
df_6.shape
# Out:
# (1392, 11)

# %% [markdown]
# We are done with Table 6. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - refugee stock: Estimated refugee stock at mid-year (both sexes)
# - year: the year of measurement

# %%
#Now we do the same with table 7
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_7.insert(2,'Major region', None )
df_7.insert(3,'Region', None )
df_7.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a)     1990 %     1995 %  \
# 15   None   NaN          900              NaN  12.346732  11.103013
# 16   None   (b)          901              NaN   2.445494   3.910511
# 17   None   (c)          902              NaN  23.968236  20.795958
# 18   None   (d)          941              NaN   45.56588  44.041961
# 19   None   NaN          934              NaN  19.919743  15.999082
#
#        2000 %     2005 %     2010 %     2015 %
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_7)
add_Region(df_7)

df_7.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a)     1990 %  \
# 15          None       None   NaN          900              NaN  12.346732
# ...

# %%
#We are creating a new column "developed/developing" 
df_7.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_7)
df_7.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_7.insert(8,'I', 0 )
df_7.insert(8,'R', 0 )
df_7.insert(8,'C', 0 )
df_7.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_7)

df_7.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#### Removing reduntant rows of regions and major regions
df_7 = df_7.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_7 = df_7.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_7 = df_7.reset_index() #Do we need brackets here
df_7 = df_7.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_7 = df_7.drop("Notes", axis = 1)
df_7 = df_7.drop("Type of data (a)", axis = 1)

df_7.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Before melting, I am going to change the names of the columns. 

df_7 = df_7.rename({"1990 %": "1990",
             "1995 %": "1995",
             "2000 %": "2000",
             "2005 %": "2005",
             "2010 %": "2010",
             "2015 %": "2015"
            }, axis = 1)

# %%
#Here we melt all the year and migrant stock columns

df_7 = df_7.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="refugee stock as %")
df_7.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 1342                                             Belize
# 1343                                         Costa Rica
# 1344                                        El Salvador
# 1345                                          Guatemala
# 1346                                           Honduras
# 1347                                             Mexico
# 1348                                          Nicaragua
# 1349                                             Panama
# 1350                                          Argentina
# 1351                   Bolivia (Plurinational State of)
# 1352                                             Brazil
# 1353                                              Chile
# 1354                                           Colombia
# 1355                                            Ecuador
# 1356                        Falkland Islands (Malvinas)
# 1357                                      French Guiana
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_7 = df_7.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i", "time":"year"})
df_7 = df_7[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "refugee stock as %","year"]]

df_7.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   refugee stock as %  year
# 0           80.43259  1990
# 1                  0  1990
# 2          44.597901  1990
# 3                  0  1990
# 4           64.21771  1990

# %%
df_7.shape
# Out:
# (1392, 11)

# %% [markdown]
# We are done with Table 7. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - refugee stock as %: Refugees as a percentage of the international migrant stock
# - year: the year of measurement

# %%
#One last cleaning left! Time for table 8.
#We are adding two extra columns to store major region and region from the second column. This way we'll have 
# a column for country, major region, and region. For example Canada will have the values: Canada, North America, North America

df_8.insert(2,'Major region', None )
df_8.insert(3,'Region', None )
df_8.head()
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
#
#    Region Notes Country code Type of data (a) 1990-1995 1995-2000 2000-2005  \
# 15   None   NaN          900              NaN -2.123497 -3.837069 -5.557223
# 16   None   (b)          901              NaN  9.388424 -5.983348 -7.277379
# 17   None   (c)          902              NaN -2.839417 -2.332154    -4.561
# 18   None   (d)          941              NaN -0.680327 -7.531747 -4.541459
# 19   None   NaN          934              NaN   -4.3836  0.632489 -4.319731
#
#    2005-2010 2010-2015
# ...

# %%
#These functions check what Major region/region a country is in and then respectively populates it in the columns
add_Major_region(df_8)
add_Region(df_8)

df_8.head(265)
# Out:
#     Sort order Major area, region, country or area of destination  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#     Major region     Region Notes Country code Type of data (a) 1990-1995  \
# 15          None       None   NaN          900              NaN -2.123497
# ...

# %%
#We are creating a new column "developed/developing" 
df_8.insert(4,'developed/developing', None )

#This function populates whether a country is developed or developing based on the NOTES section of the dataset
developing(df_8)
df_8.head(60)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#Here we are adding four columns: B, C, R, I according to the "Type of data (a)" column. 

df_8.insert(8,'I', 0 )
df_8.insert(8,'R', 0 )
df_8.insert(8,'C', 0 )
df_8.insert(8,'B', 0 )

#This function populates values to B, C, R, I according to the "Type of data (a)" column
type_of_data(df_8)

df_8.head(40)
# Out:
#    Sort order Major area, region, country or area of destination Major region  \
# 15          1                                              WORLD         None
# 16          2                                  Developed regions         None
# 17          3                                 Developing regions         None
# 18          4                          Least developed countries         None
# 19          5  Less developed regions excluding least develop...         None
# 20          6                                 Sub-Saharan Africa         None
# 21          7                                             Africa         None
# 22          8                                     Eastern Africa         None
# 23          9                                            Burundi       Africa
# 24         10                                            Comoros       Africa
# 25         11                                           Djibouti       Africa
# ...

# %%
#### Removing reduntant rows of regions and major regions
df_8 = df_8.drop([15+6,15+7,15+28,15+38,15+46,15+52,15+70,15+71,15+77,15+85,15+97,15+107,15+126,15+127,15+138,15+152,15+169,15+179,15+180,15+207,15+216,15+231,15+237,15+238,15+241,15+247,15+255])

#Removing first 6 rows of data as we don't need them
df_8 = df_8.drop([15,16,17,18,19,20], axis = 0)

#Reseting Index and dropping the rest of the index columns
df_8 = df_8.reset_index() #Do we need brackets here
df_8 = df_8.drop(["index", "Sort order"], axis = 1)

#Dropping Notes, Type of data(a)
df_8 = df_8.drop("Notes", axis = 1)
df_8 = df_8.drop("Type of data (a)", axis = 1)

df_8.tail(50)
# Out:
#     Major area, region, country or area of destination  \
# 182                                             Belize
# 183                                         Costa Rica
# 184                                        El Salvador
# 185                                          Guatemala
# 186                                           Honduras
# 187                                             Mexico
# 188                                          Nicaragua
# 189                                             Panama
# 190                                          Argentina
# 191                   Bolivia (Plurinational State of)
# 192                                             Brazil
# 193                                              Chile
# 194                                           Colombia
# 195                                            Ecuador
# 196                        Falkland Islands (Malvinas)
# 197                                      French Guiana
# ...

# %%
#Here we melt all the year and migrant stock columns

df_8 = df_8.melt(id_vars = ["Major area, region, country or area of destination", "Major region", "Region", "developed/developing", "Country code", "B", "C", "R", "I"], var_name = "time", value_name="rate of change of the refugee stock")
df_8.tail(50)
# Out:
#      Major area, region, country or area of destination  \
# 1110                                             Belize
# 1111                                         Costa Rica
# 1112                                        El Salvador
# 1113                                          Guatemala
# 1114                                           Honduras
# 1115                                             Mexico
# 1116                                          Nicaragua
# 1117                                             Panama
# 1118                                          Argentina
# 1119                   Bolivia (Plurinational State of)
# 1120                                             Brazil
# 1121                                              Chile
# 1122                                           Colombia
# 1123                                            Ecuador
# 1124                        Falkland Islands (Malvinas)
# 1125                                      French Guiana
# ...

# %%
#Time for some finishing touches. Let's rename the columns and reorder them. 
df_8 = df_8.rename(columns={"Major area, region, country or area of destination": "country", "Major region": "continent", "Region":"region", "Country code":"country code", "developed/developing":"development", "B":"b", "C":"c", "R":"r", "I": "i", "time":"period"})
df_8 = df_8[["country", "country code", "continent", "region", "development", "b", "c", "r", "i", "rate of change of the refugee stock","period"]]

df_8.head()
# Out:
#     country country code continent          region development  b  c  r  i  \
# 0   Burundi          108    Africa  Eastern Africa  Developing  1  0  1  0
# 1   Comoros          174    Africa  Eastern Africa  Developing  1  0  0  0
# 2  Djibouti          262    Africa  Eastern Africa  Developing  1  0  1  0
# 3   Eritrea          232    Africa  Eastern Africa  Developing  0  0  0  1
# 4  Ethiopia          231    Africa  Eastern Africa  Developing  1  0  1  0
#
#   rate of change of the refugee stock     period
# 0                           -3.390926  1990-1995
# 1                                  ..  1990-1995
# 2                           -9.763426  1990-1995
# 3                                  ..  1990-1995
# 4                           -5.505717  1990-1995

# %%
df_8.shape
# Out:
# (1160, 11)

# %% [markdown]
# We are done with Table 8. Here are the column descriptions:
#
# - country: the name of the country
# - country code: unique numbers identifying each country (details in the NOTES sheet of the dataset)
# - continent: the major region a country is present in
# - region: the sub-region a country is present in
# - development: indicates whether a country is developed or developing
# - b, c, r, i: details of these columns are present in the NOTES sheet of the dataset
# - rate of change of the refugee stock: annual rate of change of the refugee stock
# - period: the time period of measurement

# %% [markdown]
# ## We're done! :D

# %% [markdown]
# Let's download all the tables into a single excel file

# %%
#Took this code from Panda's documentation

with pd.ExcelWriter('UN_Migrant_Stock_Cleaned.xlsx') as writer:  
    df_1.to_excel(writer, sheet_name='Table 1')
    df_2.to_excel(writer, sheet_name='Table 2')
    df_3.to_excel(writer, sheet_name='Table 3')
    df_4.to_excel(writer, sheet_name='Table 4')
    df_5.to_excel(writer, sheet_name='Table 5')
    df_6.to_excel(writer, sheet_name='Table 6')
    df_7.to_excel(writer, sheet_name='Table 7')
    df_8.to_excel(writer, sheet_name='Table 8')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Hi there! This is my final submission for INF1340 Programming for Data Science. This time around, the code is distributed two sections:
# 1. Imports
# 2. Data Cleaning
# 3. Exploratory Data Analysis
# 4. The Story
#
# I initially fiddled around with plenty of graphs in part 3. In the report you will only find the graphs that build the narrative I am trying to create that are also present in part 4.

# %% [markdown]
# **Important Note:**
#
# Code used in this notebook is taken from the course's tutorials, in-class notebooks, and from APIs of various graphing libraries.

# %% [markdown]
# ## 1. Imports

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
from google.colab import files

# %% [markdown]
# ## 2. Data Cleaning

# %%
df_1
# Out:
#                         country country code continent          region  \
# 0                       Burundi          108    Africa  Eastern Africa
# 1                       Comoros          174    Africa  Eastern Africa
# 2                      Djibouti          262    Africa  Eastern Africa
# 3                       Eritrea          232    Africa  Eastern Africa
# 4                      Ethiopia          231    Africa  Eastern Africa
# ...                         ...          ...       ...             ...
# 4171                      Samoa          882   Oceania       Polynesia
# 4172                    Tokelau          772   Oceania       Polynesia
# 4173                      Tonga          776   Oceania       Polynesia
# 4174                     Tuvalu          798   Oceania       Polynesia
# 4175  Wallis and Futuna Islands          876   Oceania       Polynesia
#
#      development  b  c  r  i migrant stock  year  gender
# 0     Developing  1  0  1  0        333110  1990    Both
# ...

# %%
#Checking the data types of all the columns
print(df_1.dtypes)
# Out:
# country          object
# country code     object
# continent        object
# region           object
# development      object
# b                 int64
# c                 int64
# r                 int64
# i                 int64
# migrant stock    object
# year             object
# gender           object
# dtype: object

# %% [markdown]
# In my data cleaning process, I noticed some columns had ".." values. Those were replaced with NaNs.

# %%
df_1['migrant stock'] = df_1['migrant stock'].replace("..", np.nan)
df_2['total population'] = df_2['total population'].replace("..", np.nan)
df_3['migrant stock in %'] = df_3['migrant stock in %'].replace("..", np.nan)
df_4['female migrants as %'] = df_4['female migrants as %'].replace("..", np.nan)
df_5['rate of change in migrant stock'] = df_5['rate of change in migrant stock'].replace("..", np.nan)
df_6['refugee stock'] = df_6['refugee stock'].replace("..", np.nan)
df_7['refugee stock as %'] = df_7['refugee stock as %'].replace("..", np.nan)
df_8['rate of change of the refugee stock'] = df_8['rate of change of the refugee stock'].replace("..", np.nan)

# %% [markdown]
# Similarly, you can see a few cells up that the data type is incorrect for some of these columns. The following cell fixes that.

# %%
#Fixing the development column for all tables
df_1['development'] = df_1['development'].astype('category')
df_2['development'] = df_2['development'].astype('category')
df_3['development'] = df_3['development'].astype('category')
df_4['development'] = df_4['development'].astype('category')
df_5['development'] = df_5['development'].astype('category')
df_6['development'] = df_6['development'].astype('category')
df_7['development'] = df_7['development'].astype('category')
df_8['development'] = df_8['development'].astype('category')

#Fixing the gender column 
df_1['gender'] = df_1['gender'].astype('category')
df_2['gender'] = df_2['gender'].astype('category')
df_3['gender'] = df_3['gender'].astype('category')

#Fixing the year column
df_1['year'] = df_1['year'].astype('int')
df_2['year'] = df_2['year'].astype('int')
df_3['year'] = df_3['year'].astype('int')
df_4['year'] = df_4['year'].astype('int')
#Not sure what to do about table 5
df_6['year'] = df_6['year'].astype('int')
df_7['year'] = df_7['year'].astype('int')
#Not sure what to do about table 8

#Fixing the columns containing the unit of measurement for all tables
df_1['migrant stock'] = df_1['migrant stock'].astype('float')
df_2['total population'] = df_2['total population'].astype('float')
df_3['migrant stock in %'] = df_3['migrant stock in %'].astype('float')
df_4['female migrants as %'] = df_4['female migrants as %'].astype('float')
df_5['rate of change in migrant stock'] = df_5['rate of change in migrant stock'].astype('float')
df_6['refugee stock'] = df_6['refugee stock'].astype('float')
df_7['refugee stock as %'] = df_7['refugee stock as %'].astype('float')
df_8['rate of change of the refugee stock'] = df_8['rate of change of the refugee stock'].astype('float')

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# These section is where I fiddle around with different plots and subsets of the data. This was raw exploration. You will not find much useful detail here except for how I approached the dataset.

# %%
plt.style.use('seaborn-colorblind')
sns.boxplot(x=df_1["development"], y=df_1["migrant stock"])
plt.show()

# %%
df_1_sorted_a = df_1.sort_values('migrant stock', ascending=False)
df_1_sorted_d = df_1.sort_values('migrant stock', ascending=True)

# %%
temp = df_1_sorted_a.loc[df_1_sorted_a['gender'] != 'Both']

# %%
sns.boxplot(x=temp['continent'], y=temp['migrant stock'], hue = temp['gender'])

# %%
temp = df_1_sorted_a.loc[df_1_sorted_a['gender'] == 'Both']

# %%
temp = temp.loc[temp['year'] == 2015]

# %%
temp = temp.iloc[:20]
temp
# Out:
#                                                 country country code  \
# 1368                           United States of America          840
# 1310                                            Germany          276
# 1275                                 Russian Federation          643
# 1262                                       Saudi Arabia          682
# 1290  United Kingdom of Great Britain and Northern I...          826
# 1266                               United Arab Emirates          784
# 1365                                             Canada          124
# 1309                                             France          250
# 1369                                          Australia           36
# 1305                                              Spain          724
# 1298                                              Italy          380
# 1244                                              India          356
# 1277                                            Ukraine          804
# ...

# %%
viz = sns.barplot(data=temp, y='country', x='migrant stock', palette = 'colorblind')
viz.set(xlabel="Migrant Stock in 10s of millions", ylabel="Country", title="Top 10 Countries with Highest Migrant Stock")
plt.show()

# %%
temp = df_1_sorted_d.loc[df_1_sorted_d['gender'] == 'Both']
temp = temp.loc[temp['year'] == 2015]
temp = temp.iloc[:10]

# %%
viz = sns.barplot(data=temp, y='country', x='migrant stock', palette = 'colorblind')
viz.set(xlabel="Migrant Stock", ylabel="Country", title="Top 10 Countries with Lowest Migrant Stock")
plt.show()

# %%
temp = df_1.groupby(by=['continent', 'year']).sum() 
temp.head(50)
# Out:
#                                         b   c   r  i  migrant stock
# continent                       year
# Africa                          1990  117  54  99  9     31381246.0
#                                 1995  117  54  99  9     32705628.0
#                                 2000  117  54  99  9     29600612.0
#                                 2005  117  54  99  9     30382292.0
#                                 2010  117  54  99  9     33680028.0
#                                 2015  117  54  99  9     41299114.0
# Asia                            1990   87  60  75  3     96284522.0
#                                 1995   87  60  75  3     93096450.0
#                                 2000   87  60  75  3     98681630.0
#                                 2005   87  60  75  3    106742448.0
#                                 2010   87  60  75  3    131828638.0
#                                 2015   87  60  75  3    150162250.0
# ...

# %%
viz = px.bar(data_frame = df_6, x = 'year', y = 'refugee stock', facet_col = 'continent', color = 'country')
viz
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
viz = sns.lineplot(data=temp, x="year", y="migrant stock", hue="continent", palette="colorblind")
viz.set(ylabel="Migrant Stock", xlabel="Year", title="Migrant Stock of Continents over Time")
viz.legend(bbox_to_anchor= (1,1))
plt.show()

# %%
temp = df_1.groupby(by=['development', 'year']).sum() 
temp
# Out:
#                     b    c    r   i  migrant stock
# development year
# Developed   1990  150   12    9   6    164757256.0
#             1995  150   12    9   6    184613708.0
#             2000  150   12    9   6    206750726.0
#             2005  150   12    9   6    234362218.0
#             2010  150   12    9   6    265120650.0
#             2015  150   12    9   6    280963910.0
# Developing  1990  396  126  201  12    140369168.0
#             1995  396  126  201  12    136989796.0
#             2000  396  126  201  12    138655892.0
#             2005  396  126  201  12    148175982.0
#             2010  396  126  201  12    178307836.0
#             2015  396  126  201  12    206436562.0

# %%
viz = sns.lineplot(data=temp, x='year', y="migrant stock", hue="development", palette="colorblind")
#viz.set(ylabel="Migrant Stock", xlabel="Year", title="Migrant Stock of Continents over Time")
#viz.legend(bbox_to_anchor= (1,1))
#plt.show()

# %%
temp = df_1.groupby(by=['year']).sum() 
temp
# Out:
#         b    c    r   i  migrant stock
# year
# 1990  546  138  210  18    305126424.0
# 1995  546  138  210  18    321603504.0
# 2000  546  138  210  18    345406618.0
# 2005  546  138  210  18    382538200.0
# 2010  546  138  210  18    443428486.0
# 2015  546  138  210  18    487400472.0

# %%
viz = sns.lineplot(data=temp, x='year', y="migrant stock", palette="colorblind")

# %% [markdown]
# We will not do any exploration of total population from table 2 since it's incorporated in table 3. Total population on it's own can't help understand migratory patterns.

# %%
#Let's dive in with table 3
df_3
# Out:
#                         country country code continent          region  \
# 0                       Burundi          108    Africa  Eastern Africa
# 1                       Comoros          174    Africa  Eastern Africa
# 2                      Djibouti          262    Africa  Eastern Africa
# 3                       Eritrea          232    Africa  Eastern Africa
# 4                      Ethiopia          231    Africa  Eastern Africa
# ...                         ...          ...       ...             ...
# 4171                      Samoa          882   Oceania       Polynesia
# 4172                    Tokelau          772   Oceania       Polynesia
# 4173                      Tonga          776   Oceania       Polynesia
# 4174                     Tuvalu          798   Oceania       Polynesia
# 4175  Wallis and Futuna Islands          876   Oceania       Polynesia
#
#      development  b  c  r  i  migrant stock in %  year  gender
# ...

# %%
df_3_sorted_a = df_3.sort_values('migrant stock in %', ascending=False)
df_3_sorted_d = df_3.sort_values('migrant stock in %', ascending=True)

temp = df_3_sorted_a.loc[df_3_sorted_a['year'] == 2015]
temp = temp.loc[df_1_sorted_a['gender'] == 'Both']
temp = temp.iloc[:10]
temp
# Out:
#                                          country country code  \
# 1297                                    Holy See          336
# 1266                        United Arab Emirates          784
# 1261                                       Qatar          634
# 1258                                      Kuwait          414
# 1338                   Sint Maarten (Dutch part)          534
# 1311                               Liechtenstein          438
# 1292                                     Andorra           20
# 1225  China, Macao Special Administrative Region          446
# 1322                      British Virgin Islands           92
# 1313                                      Monaco          492
#
#                             continent           region development  b  c  r  \
# 1297                           Europe  Southern Europe   Developed  0  0  0
# 1266                             Asia     Western Asia  Developing  0  1  1
# ...

# %%
sns.barplot(data=temp, y="country", x="migrant stock in %")

# %%
temp = df_3_sorted_d.loc[df_3_sorted_d['year'] == 2015]
temp = temp.loc[df_1_sorted_d['gender'] == 'Both']
temp = temp.iloc[:10]
temp
# Out:
#                                     country country code  \
# 1223                                  China          156
# 1240                               Viet Nam          704
# 1324                                   Cuba          192
# 1232                              Indonesia          360
# 1166                             Madagascar          450
# 1235                                Myanmar          104
# 1249                              Sri Lanka          144
# 1226  Democratic People's Republic of Korea          408
# 1236                            Philippines          608
# 1174                                Somalia          706
#
#                             continent              region development  b  c  \
# 1223                             Asia        Eastern Asia  Developing  0  1
# 1240                             Asia  South-Eastern Asia  Developing  0  1
# 1324  Latin America and the Caribbean           Caribbean  Developing  1  0
# ...

# %%
sns.barplot(data=temp, y="country", x="migrant stock in %")

# %%
df_4_sorted_a = df_4.sort_values('female migrants as %', ascending=False)
df_4_sorted_d = df_4.sort_values('female migrants as %', ascending=True)

temp = df_4_sorted_d.loc[df_4_sorted_d['year'] == 2015]
temp = temp.iloc[:20]
temp
# Out:
#                    country country code                        continent  \
# 1242            Bangladesh           50                             Asia
# 1261                 Qatar          634                             Asia
# 1243                Bhutan           64                             Asia
# 1260                  Oman          512                             Asia
# 1266  United Arab Emirates          784                             Asia
# 1228              Mongolia          496                             Asia
# 1252               Bahrain           48                             Asia
# 1191                 Libya          434                           Africa
# 1246              Maldives          462                             Asia
# 1173            Seychelles          690                           Africa
# 1262          Saudi Arabia          682                             Asia
# 1258                Kuwait          414                             Asia
# ...

# %%
df_6_sorted_a = df_6.sort_values('refugee stock', ascending=False)
df_6_sorted_d = df_6.sort_values('refugee stock', ascending=True)

temp = df_6_sorted_a.loc[df_6_sorted_a['year'] == 2015]
temp = temp.iloc[:25]
temp
# Out:
#                                  country country code  \
# 1257                              Jordan          400
# 1263                  State of Palestine          275
# 1259                             Lebanon          422
# 1248                            Pakistan          586
# 1265                              Turkey          792
# 1245          Iran (Islamic Republic of)          364
# 1264                Syrian Arab Republic          760
# 1164                            Ethiopia          231
# 1165                               Kenya          404
# 1183                                Chad          148
# 1176                              Uganda          800
# 1223                               China          156
# 1241                         Afghanistan            4
# 1255                                Iraq          368
# 1181                            Cameroon          120
# 1368            United States of America          840
# ...

# %%
sns.barplot(data=temp, y="country", x="refugee stock")

# %%
df_7_sorted_a = df_7.sort_values('refugee stock as %', ascending=False)
df_7_sorted_d = df_7.sort_values('refugee stock as %', ascending=True)

temp = df_7_sorted_a.loc[df_7_sorted_a['year'] == 2015]
temp = temp.iloc[:25]
temp
# Out:
#                           country country code  \
# 1263           State of Palestine          275
# 1257                       Jordan          400
# 1183                         Chad          148
# 1264         Syrian Arab Republic          760
# 1259                      Lebanon          422
# 1241                  Afghanistan            4
# 1255                         Iraq          368
# 1267                        Yemen          887
# 1181                     Cameroon          120
# 1164                     Ethiopia          231
# 1211                   Mauritania          478
# 1265                       Turkey          792
# 1190                        Egypt          818
# 1165                        Kenya          404
# 1176                       Uganda          800
# 1248                     Pakistan          586
# 1193                        Sudan          729
# 1208                Guinea-Bissau          624
# 1189                      Algeria           12
# ...

# %%
temp = df_6_sorted_a[(df_6_sorted_a.country == 'Syrian Arab Republic') | (df_6_sorted_a.country == 'Turkey') | (df_6_sorted_a.country == 'Jordan') | (df_6_sorted_a.country == 'Lebanon') | (df_6_sorted_a.country == 'Iraq') | (df_6_sorted_a.country == 'Jordan') | (df_6_sorted_a.country == 'Lebanon') | (df_6_sorted_a.country == 'Egypt') ]
temp
# Out:
#                    country country code continent           region  \
# 1257                Jordan          400      Asia     Western Asia
# 1025                Jordan          400      Asia     Western Asia
# 793                 Jordan          400      Asia     Western Asia
# 1259               Lebanon          422      Asia     Western Asia
# 1265                Turkey          792      Asia     Western Asia
# 561                 Jordan          400      Asia     Western Asia
# 1032  Syrian Arab Republic          760      Asia     Western Asia
# 329                 Jordan          400      Asia     Western Asia
# 97                  Jordan          400      Asia     Western Asia
# 1264  Syrian Arab Republic          760      Asia     Western Asia
# 1027               Lebanon          422      Asia     Western Asia
# 800   Syrian Arab Republic          760      Asia     Western Asia
# 795                Lebanon          422      Asia     Western Asia
# ...

# %%
viz = sns.lineplot(data=temp, x='year', y='refugee stock', hue = 'country')

# %% [markdown]
# ##4. The Story

# %% [markdown]
# Some code and graphs from the previous section will be repeated here but with presented in the format of a story. This is where the graphs from the "Results" section of the Final submission come from.

# %%
#Let's kick things off with a box plot of refugee stock, facet wrapped by continent
viz = px.box(data_frame = df_6, x = 'year', y = 'refugee stock', facet_col = 'continent', title = 'Refugee Stock across Continents')
viz
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Grouping data by continent and year
temp = df_6.groupby(by=['continent', 'year']).sum() 
temp.head(50)
# Out:
#                                        b   c   r  i  refugee stock
# continent                       year
# Africa                          1990  39  18  33  3      5687352.0
#                                 1995  39  18  33  3      5949953.0
#                                 2000  39  18  33  3      3609138.0
#                                 2005  39  18  33  3      2750644.0
#                                 2010  39  18  33  3      2413917.0
#                                 2015  39  18  33  3      4022363.0
# Asia                            1990  29  20  25  1      9937007.0
#                                 1995  29  20  25  1      7937682.0
#                                 2000  29  20  25  1      9175210.0
#                                 2005  29  20  25  1      8109615.0
#                                 2010  29  20  25  1     10532033.0
#                                 2015  29  20  25  1     13214240.0
# ...

# %%
#Line plot of refugee stock of continents over time
viz = sns.lineplot(data=temp, x="year", y="refugee stock", hue="continent", palette="colorblind")
viz.set(ylabel="Refugee Stock", xlabel="Year", title="Refugee Stock of Continents over Time")
viz.legend(bbox_to_anchor= (1,1))
plt.show()

# %%
#Filtering data for Asia
temp = df_8
temp = temp.loc[temp['continent'] == 'Asia']
temp.head(50)
# Out:
#                                             country country code continent  \
# 58                                       Kazakhstan          398      Asia
# 59                                       Kyrgyzstan          417      Asia
# 60                                       Tajikistan          762      Asia
# 61                                     Turkmenistan          795      Asia
# 62                                       Uzbekistan          860      Asia
# 63                                            China          156      Asia
# 64   China, Hong Kong Special Administrative Region          344      Asia
# 65       China, Macao Special Administrative Region          446      Asia
# 66            Democratic People's Republic of Korea          408      Asia
# 67                                            Japan          392      Asia
# 68                                         Mongolia          496      Asia
# ...

# %%
#I tried creating a violin plot but ended up with a box plot face wrapped for region with rate of change of refugee stock as the variable under investigation
viz = px.violin(temp, y="rate of change of the refugee stock", x="period", facet_col="region", box = True, title = 'Rate of Change of Refugee Stock across Regions in Asia')
plt.show()
viz
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#This violin plot was too ugly to use. I didn't end up using it.
viz = sns.violinplot(data=temp, x="period", y="rate of change of the refugee stock", hue = 'region')
viz.set(ylabel="Rate of Change of Refugee Stock", xlabel="Time Period", title="Rate of Change of Refugee Stock in Western Asia")
plt.show()

# %%
temp = df_8
temp = temp.loc[temp['region'] == 'Western Asia']
temp.head(50)
# Out:
#                   country country code continent        region development  b  \
# 90                Armenia           51      Asia  Western Asia  Developing  1
# 91             Azerbaijan           31      Asia  Western Asia  Developing  1
# 92                Bahrain           48      Asia  Western Asia  Developing  0
# 93                 Cyprus          196      Asia  Western Asia  Developing  1
# 94                Georgia          268      Asia  Western Asia  Developing  1
# 95                   Iraq          368      Asia  Western Asia  Developing  0
# 96                 Israel          376      Asia  Western Asia  Developing  1
# 97                 Jordan          400      Asia  Western Asia  Developing  0
# 98                 Kuwait          414      Asia  Western Asia  Developing  0
# 99                Lebanon          422      Asia  Western Asia  Developing  1
# 100                  Oman          512      Asia  Western Asia  Developing  0
# ...

# %%
#Violin plot of rate of change of refugee stock on Western Asia
viz = sns.violinplot(data=temp, x="period", y="rate of change of the refugee stock")
viz.set(ylabel="Rate of Change of Refugee Stock", xlabel="Time Period", title="Rate of Change of Refugee Stock in Western Asia")
plt.show()

# %%
#Creating two dataframes, one for ascending and one for descending refugee stock
df_6_sorted_a = df_6.sort_values('refugee stock', ascending=False)
df_6_sorted_d = df_6.sort_values('refugee stock', ascending=True)

temp = df_6_sorted_a.loc[df_6_sorted_a['year'] == 2015]
temp = temp.iloc[:20]
temp
# Out:
#                          country country code         continent  \
# 1257                      Jordan          400              Asia
# 1263          State of Palestine          275              Asia
# 1259                     Lebanon          422              Asia
# 1248                    Pakistan          586              Asia
# 1265                      Turkey          792              Asia
# 1245  Iran (Islamic Republic of)          364              Asia
# 1264        Syrian Arab Republic          760              Asia
# 1164                    Ethiopia          231            Africa
# 1165                       Kenya          404            Africa
# 1183                        Chad          148            Africa
# 1176                      Uganda          800            Africa
# 1223                       China          156              Asia
# 1241                 Afghanistan            4              Asia
# 1255                        Iraq          368              Asia
# ...

# %%
#We are now sorting the data for refugee stock
viz = sns.barplot(data=temp, y="country", x="refugee stock", palette = "colorblind")
viz.set(xlabel="Refugee Stock (in millions)", ylabel="Country", title="Top 20 Countries with Highest Refugee Stock")
plt.show()
viz.figure.savefig("output.png")

# %%
#We are now subseting the data to have a look at countries neighbouring Syria as well as Syria itself.
temp = df_6_sorted_a[(df_6_sorted_a.country == 'Syrian Arab Republic') | (df_6_sorted_a.country == 'Turkey') | (df_6_sorted_a.country == 'Jordan') | (df_6_sorted_a.country == 'Lebanon') | (df_6_sorted_a.country == 'Iraq') | (df_6_sorted_a.country == 'Jordan') | (df_6_sorted_a.country == 'Lebanon') | (df_6_sorted_a.country == 'Egypt') ]

viz = sns.lineplot(data=temp, x='year', y='refugee stock', hue = 'country')
viz.set(ylabel="Refugee Stock (", xlabel="Year", title="Refugee Stock of Select Countries over Time")
viz.legend(bbox_to_anchor= (1,1))
plt.show()

# %%
#We would like to have a look at total population as well
#We will only look at Syria 
temp = df_2
temp = temp.loc[temp['country'] == 'Syrian Arab Republic']
temp = temp.loc[temp['gender'] != 'Both']
temp
# Out:
#                    country country code continent        region development  \
# 1496  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 1728  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 1960  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 2192  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 2424  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 2656  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 2888  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 3120  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 3352  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 3584  Syrian Arab Republic          760      Asia  Western Asia  Developing
# 3816  Syrian Arab Republic          760      Asia  Western Asia  Developing
# ...

# %%
#A plot of the total population of Syria
viz = sns.lineplot(data=temp, x='year', y='total population', hue = 'gender')
viz.set(ylabel="Total Population (in 1000s)", xlabel="Year", title="Total Population of Syria")
viz.legend(bbox_to_anchor= (1,1))

plt.show()

# %%
#Subsetting the data for Germany, Sweden, and Netherlands: non-neighbouring countries that accepted a lot of Syrian Refugees
temp = df_1[(df_1.country == 'Germany') | (df_1.country == 'Sweden') | (df_1.country == 'Netherlands')]
temp = temp.loc[temp['gender'] == 'Both']
temp
# Out:
#           country country code continent           region development  b  c  \
# 129        Sweden          752    Europe  Northern Europe   Developed  1  0
# 150       Germany          276    Europe   Western Europe   Developed  1  0
# 154   Netherlands          528    Europe   Western Europe   Developed  1  0
# 361        Sweden          752    Europe  Northern Europe   Developed  1  0
# 382       Germany          276    Europe   Western Europe   Developed  1  0
# 386   Netherlands          528    Europe   Western Europe   Developed  1  0
# 593        Sweden          752    Europe  Northern Europe   Developed  1  0
# 614       Germany          276    Europe   Western Europe   Developed  1  0
# 618   Netherlands          528    Europe   Western Europe   Developed  1  0
# 825        Sweden          752    Europe  Northern Europe   Developed  1  0
# 846       Germany          276    Europe   Western Europe   Developed  1  0
# ...

# %%
#A peek into Migrant Stock of non-neighbouring countries
viz = sns.lineplot(data=temp, x='year', y='migrant stock', hue = 'country')
viz.set(ylabel="Migrant Stock (in 10s of millions)", xlabel="Year", title="Migrant Stock of Select Countries over Time")
viz.legend(bbox_to_anchor= (1,1))
plt.show()

# %%
#One last look at Migrant Stock of neighbouring countries of Syria
temp = df_1[ (df_1.country == 'Turkey') | (df_1.country == 'Iraq') | (df_1.country == 'Jordan') | (df_1.country == 'Lebanon') | (df_1.country == 'Egypt') ]
temp = temp.loc[temp['gender'] == 'Both']
viz = sns.lineplot(data=temp, x='year', y='migrant stock', hue = 'country')
viz.set(ylabel="Migrant Stock (in millions)", xlabel="Year", title="Migrant Stock of Select Countries over Time")
viz.legend(bbox_to_anchor= (1,1))
plt.show()
